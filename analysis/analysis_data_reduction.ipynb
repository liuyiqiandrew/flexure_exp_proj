# %%
import numpy as np
import scipy.stats as stt
import matplotlib.pyplot as plt
import analysis_utils as utils

# %%
path = '../data/buckling/cryo/x_f_8in_332_{}.npz'
x332_8c, f332_8c, xerr332_8c, ferr322_8c= utils.plot_offset_corrected_raw(path, range(5), fit_min=150, fit_max=500)
# path = '../data/buckling/x_f_8in_332_{}.npz'
# x332_8, f332_8 = utils.plot_offset_corrected_raw(path, range(3), fit_min=120, fit_max=300)
# path = '../data/buckling/x_f_6in_332_{}.npz'
# x332_6, f332_6 = utils.plot_offset_corrected_raw(path, range(3), fit_min=170, fit_max=500)

# %%
path = '../data/buckling/cryo/x_f_8in_332_{}.npz'
x332_8c_raw, f332_8c_raw, xerr332_8c_raw, ferr332_8c_raw = utils.get_raw(path, range(5))
path = '../data/buckling/x_f_8in_332_{}.npz'
x332_8_raw, f332_8_raw, xerr332_8_raw, ferr332_8_raw = utils.get_raw(path, range(3))
path = '../data/buckling/x_f_6in_332_{}.npz'
x332_6_raw, f332_6_raw, xerr332_6_raw, ferr332_6_raw = utils.get_raw(path, range(3))

# %%
plt.figure(dpi=300)
plt.scatter(x332_8c_raw, f332_8c_raw, s=3)
plt.scatter(x332_8_raw, f332_8_raw, s=3)
plt.scatter(x332_6_raw, f332_6_raw, s=3)

# %%
plt.figure(dpi=300)
plt.scatter(x332_8c, f332_8c, s=2, alpha=.5)
plt.scatter(x332_8_raw, f332_8_raw, s=2, alpha=.5)
plt.scatter(x332_6_raw, f332_6_raw, s=2, alpha=.5)

# %%
np.savez("../data/clean_analysis/buckling/bk332_8_cryo.npz", x=x332_8c, f=f332_8c, xerr=xerr332_8c, ferr=ferr322_8c)
np.savez("../data/clean_analysis/buckling/bk332_8_rt.npz", x=x332_8_raw, f=f332_8_raw, xerr=xerr332_8_raw, ferr=ferr332_8_raw)
np.savez("../data/clean_analysis/buckling/bk332_6_rt.npz", x=x332_6_raw, f=f332_6_raw, xerr=xerr332_6_raw, ferr=ferr332_6_raw)

# %%
path = '../data/buckling/cryo/x_f_8in_116_{}.npz'
x116_8c, f116_8c = utils.plot_offset_corrected_raw(path, range(5), fit_min=75, fit_max=200)
path = '../data/buckling/x_f_8in_116_{}.npz'
x116_8, f116_8 = utils.plot_offset_corrected_raw(path, range(3), fit_min=50, fit_max=160)
path = '../data/buckling/x_f_6in_116_{}.npz'
x116_6, f116_6 = utils.plot_offset_corrected_raw(path, range(3), fit_min=80, fit_max=170)

# %%
plt.figure(dpi=300)
plt.scatter(x116_8c, f116_8c, s=2, alpha=.5)
plt.scatter(x116_8, f116_8, s=2, alpha=.5)
plt.scatter(x116_6, f116_6, s=2, alpha=.5)

# %%
path = '../data/buckling/cryo/x_f_8in_116_{}.npz'
x116_8c_raw, f116_8c_raw, xerr116_8c_raw, ferr116_8c_raw = utils.get_raw(path, range(5))
path = '../data/buckling/x_f_8in_116_{}.npz'
x116_8_raw, f116_8_raw, xerr116_8_raw, ferr116_8_raw = utils.get_raw(path, range(3))
path = '../data/buckling/x_f_6in_116_{}.npz'
x116_6_raw, f116_6_raw, xerr116_6_raw, ferr116_6_raw = utils.get_raw(path, range(3))

# %%
plt.figure(dpi=300)
plt.scatter(x116_8c_raw, f116_8c_raw, s=3)
plt.scatter(x116_8_raw, f116_8_raw, s=3)
plt.scatter(x116_6_raw, f116_6_raw, s=3)

# %%
np.savez("../data/clean_analysis/buckling/bk116_8_cryo.npz", x=x116_8c_raw, f=f116_8c_raw, xerr=xerr116_8c_raw, ferr=ferr116_8c_raw)
np.savez("../data/clean_analysis/buckling/bk116_8_rt.npz", x=x116_8_raw, f=f116_8_raw, xerr=xerr116_8_raw, ferr=ferr116_8_raw)
np.savez("../data/clean_analysis/buckling/bk116_6_rt.npz", x=x116_6_raw, f=f116_6_raw, xerr=xerr116_6_raw, ferr=ferr116_6_raw)
